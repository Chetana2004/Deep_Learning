# %%
# --- a. Data Preparation ---

import numpy as np
import re
from collections import defaultdict

# %%
# Load the text file
with open("CBOW.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# %%
# Clean and tokenize
text = re.sub(r'[^a-z\s]', '', text)
words = text.split()
print("Total words:", len(words))
print("Sample words:", words[:20])
# Out:
# Total words: 177
# Sample words: ['the', 'speed', 'of', 'transmission', 'is', 'an', 'important', 'point', 'of', 'difference', 'between', 'the', 'two', 'viruses', 'influenza', 'has', 'a', 'shorter', 'median', 'incubation']

# %%
# Create vocabulary and mappings
vocab = sorted(set(words))
vocab_size = len(vocab)

word_to_index = {word: i for i, word in enumerate(vocab)}
index_to_word = {i: word for word, i in word_to_index.items()}

print("Vocabulary size:", vocab_size)
print("Example mapping:", list(word_to_index.items())[:10])
# Out:
# Vocabulary size: 92
# Example mapping: [('a', 0), ('an', 1), ('and', 2), ('appear', 3), ('appearance', 4), ('are', 5), ('at', 6), ('be', 7), ('before', 8), ('between', 9)]

# %%
def generate_cbow_data(tokens, w2i, vsize, wsize):
    X, Y = [], []
    for i, t in enumerate(tokens):
        ctx = [tokens[j] for j in range(i-wsize, i+wsize+1) if j!=i and 0<=j<len(tokens)]
        if not ctx: continue
        x = np.zeros(vsize); [x.__setitem__(w2i[w], x[w2i[w]]+1) for w in ctx]
        y = np.zeros(vsize); y[w2i[t]] = 1
        X.append(x); Y.append(y)
    X, Y = np.array(X, 'float32'), np.array(Y, 'float32')
    print(f"✅ {len(X)} samples | Input Shape:{X.shape} | Output Shape:{Y.shape}")
    return X, Y

# Call the function
WINDOW_SIZE = 2
X_cbow, Y_cbow = generate_cbow_data(words, word_to_index, vocab_size, WINDOW_SIZE)
# Out:
# ✅ 177 samples | Input Shape:(177, 92) | Output Shape:(177, 92)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

# --- d. CBOW Model Training ---
EMBEDDING_DIM = 100
EPOCHS = 100

model = Sequential([
    Input(shape=(vocab_size,), name="Input_Layer"),
    Dense(EMBEDDING_DIM, activation='linear', name='Embedding'),
    Dense(vocab_size, activation='softmax', name='Output')
])

model.compile(optimizer=Adam(0.01), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Embedding (Dense)                    │ (None, 100)                 │           9,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 92)                  │           9,292 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,592 (72.62 KB)
#  Trainable params: 18,592 (72.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(f"\nTraining CBOW model for {EPOCHS} epochs...")
model.fit(X_cbow, Y_cbow, epochs=EPOCHS, verbose=1)
print("\n✅ CBOW model training complete.")
# Out:
# Training CBOW model for 100 epochs...
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0226 - loss: 4.5377
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3842 - loss: 3.6771
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4802 - loss: 2.9262
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5424 - loss: 2.2530
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7345 - loss: 1.5981
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8927 - loss: 1.0563
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9322 - loss: 0.6803
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9718 - loss: 0.4342
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9774 - loss: 0.2927
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9831 - loss: 0.2070
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.1517
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.1156
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0931
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0787
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0677
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0595
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0542
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0470
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.0448
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0408
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9887 - loss: 0.0409
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9887 - loss: 0.0353
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0331
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9887 - loss: 0.0309
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9887 - loss: 0.0304
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0280
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0287
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0274
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0253
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0242
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0222
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0229
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0211
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0211
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0205
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0266
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9887 - loss: 0.0340
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0281
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0177
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0258
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0211
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0259
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9887 - loss: 0.0184
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0170
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0174
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0204
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0164
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0146
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0194
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0153
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0246
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0200
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0122
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0210
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0172
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0133
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0165
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0135
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0150
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0134
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0152
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0137
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0153
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0141
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0118
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0135
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.0129
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0166
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0112
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0187
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0147
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0120
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0139
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9887 - loss: 0.0152
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9887 - loss: 0.0126
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0150
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0130
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0126
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0113
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0150
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9887 - loss: 0.0138
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0119
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0153
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0101
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0158
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0142
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0127
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0133
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 0.0127
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0136
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0141
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0109
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0102
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0131
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9887 - loss: 0.0143
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0123
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0106
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0099
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0114
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9887 - loss: 0.0139
#
# ✅ CBOW model training complete.

# %%
# --- Extract & Display Word Embeddings ---
embeddings = model.get_layer('Embedding').get_weights()[0]
print("Embedding matrix shape:", embeddings.shape)

word = 'learning'
if word in word_to_index:
    print(f"\n'{word}' embedding (first 5 dims):", embeddings[word_to_index[word]][:5])
else:
    print(f"'{word}' not in vocabulary.")

# --- Predict Target Word ---
def predict(context, model, w2i, i2w, vocab_size):
    vec = np.zeros((1, vocab_size))
    for w in context:
        if w in w2i: vec[0, w2i[w]] += 1
    probs = model.predict(vec, verbose=0)[0]
    idx = np.argmax(probs)
    return i2w[idx], probs[idx]

# --- Example ---
context = ['shorter', 'incubation', 'period']
word, p = predict(context, model, word_to_index, index_to_word, vocab_size)
print(f"\nContext: {context}\nPredicted: '{word}' (p={p:.4f})")
# Out:
# Embedding matrix shape: (92, 100)
#
# 'learning' embedding (first 5 dims): [-0.00434319 -0.49688897 -0.02037597  0.23936544  0.21846247]
#
# Context: ['shorter', 'incubation', 'period']
# Predicted: 'median' (p=0.9434)
